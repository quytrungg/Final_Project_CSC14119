# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import set_config
import seaborn as sns; sns.set()
set_config(display='diagram')

# %%
#Read albums' data from tsv

pd_album = pd.read_csv('albums_data.tsv', sep='\t')
pd_album
# Out:
#                           id  \
# 0     7lPoGKpCGgdKFAxpudhAH5
# 1     0gr5OmB74UhoANEXwYT3gE
# 2     6al2VdKbb6FIz9d7lU7WRB
# 3     6oSxSPOg7Kuitjt2zwP7sU
# 4     4uDaEWj8W206qyyyndHri9
# ...                      ...
# 2995  4L9AVldyJCKBOjWLMZieW0
# 2996  4EaxXFlLmcARrR4svYOBPG
# 2997  6vyjuun6BIWGkkUKseUVzf
# 2998  3jCbuVrvccIww2TZrz8xPB
# 2999  0kmBEk4CbklFQljNVMbpqL
#
#                                                    name  popularity  \
# 0                              Speak Your Mind (Deluxe)          72
# 1     Dreamers [Music from the FIFA World Cup Qatar ...          67
# 2                                                 Proof          85
# 3                                                  2002          52
# 4                        2022 Tanging Ain't Dead Cypher          36
# ...                                                 ...         ...
# 2995                                        2020 Vision          41
# ...

# %%
pd_album.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 3000 non-null   object
#  1   name               3000 non-null   object
#  2   popularity         3000 non-null   int64
#  3   available_markets  3000 non-null   int64
#  4   release_date       3000 non-null   object
#  5   total_tracks       3000 non-null   int64
# dtypes: int64(3), object(3)
# memory usage: 140.8+ KB

# %%
#Number of rows and columns of data

num_rows = len(pd_album)
num_cols = len(pd_album.columns)
num_rows, num_cols
# Out:
# (3000, 6)

# %%
#Data type of each columns

dtypes = pd_album.dtypes
dtypes
# Out:
# id                   object
# name                 object
# popularity            int64
# available_markets     int64
# release_date         object
# total_tracks          int64
# dtype: object

# %%
albums_data_des = pd.read_csv('albums_data_des.csv')
albums_data_des
# Out:
#          column name  data type  \
# 0                 id     string
# 1               name     string
# 2         popularity        int
# 3  available_markets        int
# 4       release_date     string
# 5       total_tracks        int
#
#                                              meaning  \
# 0                        The Spotify ID of the album
# 1                              The name of the album
# 2   "The popularity of the album. The value will ...
# 3   The number of markets (countries) which the a...
# 4                The day when the album was released
# 5       The number of tracks which the album contain
#
#                      example
# 0     7lPoGKpCGgdKFAxpudhAH5
# 1   Speak Your Mind (Deluxe)
# 2                         72
# 3                        183
# 4               "2018-04-27"
# 5                         18

# %%
#Count how many duplicated albums' id

pd_album['id'].duplicated().value_counts()
# Out:
# True     1761
# False    1239
# Name: id, dtype: int64

# %%
#Show off

num_duplicated_rows = pd_album.duplicated()

pd_album[num_duplicated_rows == False]
# Out:
#                           id  \
# 0     7lPoGKpCGgdKFAxpudhAH5
# 1     0gr5OmB74UhoANEXwYT3gE
# 2     6al2VdKbb6FIz9d7lU7WRB
# 3     6oSxSPOg7Kuitjt2zwP7sU
# 4     4uDaEWj8W206qyyyndHri9
# ...                      ...
# 2993  2XXF6pODroMYQ3qPmXeMB1
# 2994  1zTte6jrgPExyHmoytoUue
# 2997  6vyjuun6BIWGkkUKseUVzf
# 2998  3jCbuVrvccIww2TZrz8xPB
# 2999  0kmBEk4CbklFQljNVMbpqL
#
#                                                    name  popularity  \
# 0                              Speak Your Mind (Deluxe)          72
# 1     Dreamers [Music from the FIFA World Cup Qatar ...          67
# 2                                                 Proof          85
# 3                                                  2002          52
# 4                        2022 Tanging Ain't Dead Cypher          36
# ...                                                 ...         ...
# 2993                  Mona Bone Jakon (Remastered 2020)          50
# ...

# %%
#Count how much time an album occur

album_occur = pd_album.pivot_table(columns = pd_album[['id', 'name']], aggfunc = 'size')
album_occur
# Out:
# id                      name
# 000t7Ge3vazfHDgDwYV8dZ  Natale 2020                                   1
# 00BTANHgZ5QUmFI0JYlGMR  2020 Takeover                                 4
# 00Icx0sKUAfNFcJeK1L6DW  2021                                          1
# 00RxYCXCK9vr6ee1n68Qqx  X6                                            1
# 00qm7Vvf02HhbJIhR6AplQ  Musica Binaural para Dormir Profundamente     1
#                                                                      ..
# 7ySWVfhfhHfUZHyCfbNWd7  Hold On (feat. Cheat Codes) [2020 Edit]       3
# 7ysE18Qc9SBTqQxt1dqa4O  Dembow Mix 2021                               1
# 7zHLNk5qYXQsqrlyz8HMeP  Raphaela Santos A Favorita 2021               1
# 7zb6pXoaflVYQ5udHC68DU  2020                                          1
# 7zva9wg87euC958GKmscJz  Festa di Capodanno 2022                      30
# Length: 1239, dtype: int64

# %%
#Write albums' occurrences to tsv

new_column_names = ['occurrences']

album_occur.to_csv('albums_occurrences.tsv', header=new_column_names, sep = '\t')

# %%
df = pd.read_csv('albums_occurrences.tsv', sep = '\t')
df
# Out:
#                           id                                       name  \
# 0     000t7Ge3vazfHDgDwYV8dZ                                Natale 2020
# 1     00BTANHgZ5QUmFI0JYlGMR                              2020 Takeover
# 2     00Icx0sKUAfNFcJeK1L6DW                                       2021
# 3     00RxYCXCK9vr6ee1n68Qqx                                         X6
# 4     00qm7Vvf02HhbJIhR6AplQ  Musica Binaural para Dormir Profundamente
# ...                      ...                                        ...
# 1234  7ySWVfhfhHfUZHyCfbNWd7    Hold On (feat. Cheat Codes) [2020 Edit]
# 1235  7ysE18Qc9SBTqQxt1dqa4O                            Dembow Mix 2021
# 1236  7zHLNk5qYXQsqrlyz8HMeP            Raphaela Santos A Favorita 2021
# 1237  7zb6pXoaflVYQ5udHC68DU                                       2020
# 1238  7zva9wg87euC958GKmscJz                    Festa di Capodanno 2022
#
#       occurrences
# 0               1
# 1               4
# 2               1
# 3               1
# ...

# %%
#Sort occurrences by descending order

album_occur = df.sort_values(by = 'occurrences', ascending = False)
album_occur
# Out:
#                           id                                name  occurrences
# 1098  6tMXhYSWXf3xcbrEQgNckz    Capodanno 2022 Baila! Latin Hits           66
# 360   2HQ1QwLkpqd5Jn0u5oskim              this was 2022 the hits           48
# 1208  7nII01joxrmJU3KQPLejxV                         2022 Rewind           41
# 1037  6QIWJVJPPgAA5c4aIb1zCA                             SKZ2020           40
# 995   69tpCFA80jyssTOIHDQQO8             Capodanno 2022 Pop Hits           38
# ...                      ...                                 ...          ...
# 571   3d2KbmqejpYTVz5YhXyyPV                                2021            1
# 572   3dkf9puzuYKKlNRlgEQndL  2020 Vision (feat. El Rass & Zoog)            1
# 575   3euz4vS7ezKGnNSwgyvKcd                           Positions            1
# 576   3f0NeEKuDPV0uVCpt131Bw   Rojo Navidad (2020 Remasterizado)            1
# 0     000t7Ge3vazfHDgDwYV8dZ                         Natale 2020            1
#
# [1239 rows x 3 columns]

# %%
#Visualization of top 10 albums' occurrences among 3000 songs

top10_occurrences = album_occur[['name', 'occurrences']].nlargest(n = 10, columns = ['occurrences'])
top10_occurrences.set_index('name').plot.barh(figsize = (10, 10))
# Out:
# <AxesSubplot: ylabel='name'>

# %%
#Drop duplicated rows

dropped_album = pd_album.drop_duplicates(subset=['id'], keep='first', inplace=False)
dropped_album
# Out:
#                           id  \
# 0     7lPoGKpCGgdKFAxpudhAH5
# 1     0gr5OmB74UhoANEXwYT3gE
# 2     6al2VdKbb6FIz9d7lU7WRB
# 3     6oSxSPOg7Kuitjt2zwP7sU
# 4     4uDaEWj8W206qyyyndHri9
# ...                      ...
# 2993  2XXF6pODroMYQ3qPmXeMB1
# 2994  1zTte6jrgPExyHmoytoUue
# 2997  6vyjuun6BIWGkkUKseUVzf
# 2998  3jCbuVrvccIww2TZrz8xPB
# 2999  0kmBEk4CbklFQljNVMbpqL
#
#                                                    name  popularity  \
# 0                              Speak Your Mind (Deluxe)          72
# 1     Dreamers [Music from the FIFA World Cup Qatar ...          67
# 2                                                 Proof          85
# 3                                                  2002          52
# 4                        2022 Tanging Ain't Dead Cypher          36
# ...                                                 ...         ...
# 2993                  Mona Bone Jakon (Remastered 2020)          50
# ...

# %%
#Visualization of top 10 albums' number of tracks

top10_notracks = dropped_album[['name', 'total_tracks']].nlargest(n = 10, columns = ['total_tracks'])
top10_notracks.set_index('name').plot.barh(figsize = (10, 10))
# Out:
# <AxesSubplot: ylabel='name'>

# %%
#List all albums have popularity over 80

dropped_album[dropped_album['popularity'] > 80].sort_values(by = ['popularity'], ascending = False)
# Out:
#                           id                                      name  \
# 117   5r36AJ6VOJtp00oxSkBZ5h                             Harry's House
# 9     0gX9tkL5njRax8ymWcXARi                 Unholy (feat. Kim Petras)
# 115   7M842DMhYVALrXsw3ty7B3                           I'm Good (Blue)
# 2     6al2VdKbb6FIz9d7lU7WRB                                     Proof
# 152   1nAQbHeOWTfQzbOoFrvndW                                Planet Her
# 2151  0S0KGZnfBGSIssfF54WSJh  WHEN WE ALL FALL ASLEEP, WHERE DO WE GO?
# 17    2pqdSWeJVsXAhHFuVLzuA8                                 As It Was
# 111   1HMLpmZAnNyl9pxvOnTovV               NewJeans 1st EP 'New Jeans'
#
#       popularity  available_markets release_date  total_tracks
# 117           91                183   2022-05-20            13
# 9             88                182   2022-09-22             1
# 115           86                182   2022-08-26             2
# 2             85                183   2022-06-10            35
# ...

# %%
#Visualization of top 10 albums' popularity

top10_popularity = dropped_album[['name', 'popularity']].nlargest(n = 10, columns = ['popularity'])
top10_popularity.set_index('name').plot.barh(figsize = (10, 10))
# Out:
# <AxesSubplot: ylabel='name'>
