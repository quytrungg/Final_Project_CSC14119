# %%
import pandas as pd

# %%
pd_album = pd.read_csv('album_data.tsv', sep='\t')
pd_album
# Out:
#                          id                         name  popularity  \
# 0    1WRiN6skJPCcnoP99a0oIQ               2022 Freestyle          40
# 1    0TJbHn3Cx2UhILpiinvHlV               Christmas 2022           0
# 2    40py8Fn35TC6GnszSKccjZ                   Past Lives          53
# 3    1B7uQCvD30tJVF3O5pQw6Z         Merry Christmas 2022           0
# 4    7lPoGKpCGgdKFAxpudhAH5     Speak Your Mind (Deluxe)          72
# ..                      ...                          ...         ...
# 995  0xkKzTdvWzS8DA4hzyQijn             Let It Snow 2022           0
# 996  0xkKzTdvWzS8DA4hzyQijn             Let It Snow 2022           0
# 997  4CnAmH7lC1pdSGjN3vfahA     Top Christmas Songs 2022           7
# 998  4oEVFKmJKkgmU0zKfq5sVC  Santa Baby - Christmas 2022          11
# 999  0xkKzTdvWzS8DA4hzyQijn             Let It Snow 2022           0
#
#      available markets release date  total tracks
# 0                  183   2022-04-22             1
# 1                   95   2022-11-18            37
# 2                  182   2022-11-11            11
# 3                   95   2022-11-18            40
# 4                  183   2018-04-27            18
# ..                 ...          ...           ...
# 995                 95   2022-11-17            85
# 996                 95   2022-11-17            85
# 997                 95   2022-11-15            80
# 998                 95   2022-11-08            80
# 999                 95   2022-11-17            85
#
# [1000 rows x 6 columns]

# %%
pd_album.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 1000 non-null   object
#  1   name               1000 non-null   object
#  2   popularity         1000 non-null   int64
#  3   available markets  1000 non-null   int64
#  4   release date       1000 non-null   object
#  5   total tracks       1000 non-null   int64
# dtypes: int64(3), object(3)
# memory usage: 47.0+ KB

# %%
num_rows = len(pd_album)
num_cols = len(pd_album.columns)
num_rows, num_cols
# Out:
# (1000, 6)

# %%
dtypes = pd_album.dtypes
dtypes
# Out:
# id                   object
# name                 object
# popularity            int64
# available markets     int64
# release date         object
# total tracks          int64
# dtype: object

# %%
count = 0
for id in pd_album['id'].unique():
    count += 1

count
# Out:
# 252

# %%
num_duplicated_rows = pd_album.duplicated()

pd_album[num_duplicated_rows == False]
# Out:
#                          id                                        name  \
# 0    1WRiN6skJPCcnoP99a0oIQ                              2022 Freestyle
# 1    0TJbHn3Cx2UhILpiinvHlV                              Christmas 2022
# 2    40py8Fn35TC6GnszSKccjZ                                  Past Lives
# 3    1B7uQCvD30tJVF3O5pQw6Z                        Merry Christmas 2022
# 4    7lPoGKpCGgdKFAxpudhAH5                    Speak Your Mind (Deluxe)
# ..                      ...                                         ...
# 949  2O4UbvPRJvaK7w1Ebub951                 Türkishe Hip Hop & Rap 2022
# 952  5h3yp4glFk8e098g3f0f1E  ASOT 1095 - A State Of Trance Episode 1095
# 979  4DCIc6AsRGKdKLh2bDfQr0                          Pure Acoustic 2022
# 981  3eWcXbAhQf8rniTQ7u2JDB  Estrellita De Madrugada (Ft. Daddy Yankee)
# 993  1YnYdZrfgtie2NvTsNUAIQ                            Heartbroken 2022
#
#      popularity  available markets release date  total tracks
# 0            40                183   2022-04-22             1
# 1             0                 95   2022-11-18            37
# 2            53                182   2022-11-11            11
# 3             0                 95   2022-11-18            40
# 4            72                183   2018-04-27            18
# ..          ...                ...          ...           ...
# 949           1                 91   2022-11-04            31
# 952          24                183   2022-11-17            51
# 979          42                 95   2022-03-18            40
# 981          53                183   2022-08-26             3
# 993          47                182   2022-06-27             1
#
# [252 rows x 6 columns]
