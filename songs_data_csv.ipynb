# %%
import numpy as np
import pandas as pd

# %%
songs_data = pd.read_csv('songs_data.tsv', sep='\t')

# %%
songs_data.head()
# Out:
#                        id                            name             artist  \
# 0  0V3wPSX9ygBnCm8psDIegu                       Anti-Hero   ['Taylor Swift']
# 1  2pIUpMhHL6L9Z5lnKxJJr9                       Attention       ['NewJeans']
# 2  3TSLqZssCoCdDlMhCJ08XW                      Still Life        ['BIGBANG']
# 3  7EyhPjrJzjx0fk2i7vUJCS                      Pink Venom      ['BLACKPINK']
# 4  53JDP7TaGacjUtnStYQp51  CƠN MƯA NGANG QUA - REMIX 2022  ['Sơn Tùng M-TP']
#
#     followers artist popularity  markets                           album  \
# 0  [61488932]             [100]      182                       Midnights
# 1    [850212]              [74]      183     NewJeans 1st EP 'New Jeans'
# 2   [4931939]              [64]      182                      Still Life
# 3  [34043383]              [86]       54                      Pink Venom
# 4   [3789324]              [57]      183  CƠN MƯA NGANG QUA (REMIX 2022)
#
#   release date  duration  explicit  local  popularity
# 0   2022-10-21    200690     False  False          96
# 1   2022-08-01    180066     False  False          85
# 2   2022-04-05    188369     False  False          66
# 3   2022-08-19    186964     False  False          81
# 4   2022-06-07    236716     False  False          45

# %%
songs_train = songs_data.iloc[50:]
songs_test = songs_data.iloc[:50]

# %%
song_features = songs_train.iloc[:, :-1]
song_label = songs_train.iloc[:, -1]

# %%
song_features.head()
# Out:
#                         id                       name  \
# 50  2BgEsaKNfHUdlh97KmvFyo                       2002
# 51  3nqQXoyQOWXiESFLlDF1hG  Unholy (feat. Kim Petras)
# 52  5HCyWlXZPP0y6Gqq8TgA20  STAY (with Justin Bieber)
# 53  74dZm72WtQx122nyIFhJAB                 Em Đã Biết
# 54  4zCIxSnVWpGNghERX4uWZF         SMILEY(Feat. BIBI)
#
#                                 artist            followers artist popularity  \
# 50                      ['Anne-Marie']           [10171858]              [76]
# 51         ['Sam Smith', 'Kim Petras']   [20625240, 819552]          [87, 82]
# 52  ['The Kid LAROI', 'Justin Bieber']  [4063630, 67092153]          [80, 89]
# 53                    ['Suni Hạ Linh']             [186735]              [51]
# 54                    ['YENA', 'BIBI']     [238460, 545235]          [52, 67]
#
#     markets                      album release date  duration  explicit  local
# 50      183   Speak Your Mind (Deluxe)   2018-04-27    186986     False  False
# 51      182  Unholy (feat. Kim Petras)   2022-09-22    156943     False  False
# 52      182  STAY (with Justin Bieber)   2021-07-09    141805      True  False
# 53      183                 Em Đã Biết   2016-03-17    261321     False  False
# 54      183               ˣ‿ˣ (SMiLEY)   2022-01-17    173413     False  False

# %%
pd.DataFrame(song_label).head()
# Out:
#     popularity
# 50          81
# 51         100
# 52          87
# 53          47
# 54          66
