# %%
import numpy as np
import pandas as pd
from datetime import datetime

# %%
raw_data = pd.read_csv('songs_data.tsv', sep='\t')
raw_data.head()
# Out:
#                        id                             name             artist  \
# 0  2BgEsaKNfHUdlh97KmvFyo                             2002         Anne-Marie
# 1  4Pbg79cTBu4vgSphoyNq3j                             2002         Anne-Marie
# 2  2zYc8JUkCUqY7r567OzpUc             Replay trên con Guây     Phuc Du,Đan Ni
# 3  3gZyjgWdEibTsQFEmGiSSk    2022 World Championship Theme  League of Legends
# 4  5aucVLKiumD89mxVCB4zvS  Rush Hour (Feat. j-hope of BTS)       Crush,j-hope
#
#                                               genres         followers  \
# 0  dance pop,pop,pop dance,post-teen pop,tropical...          10179165
# 1  dance pop,pop,pop dance,post-teen pop,tropical...          10179165
# 2                                              v-pop           15757,5
# 3                          speedrun,video game music           1515248
# 4                       k-pop,korean r&b,k-pop,k-rap  1049749,12281987
#
#   artist popularity  markets                          album release date  \
# 0                76      183       Speak Your Mind (Deluxe)   2018-04-27
# 1                76      183                           2002   2018-04-19
# 2             46,36      183           Replay trên con Guây   2022-10-10
# 3                78      183  2022 World Championship Theme   2022-09-07
# 4             67,73      180                      Rush Hour   2022-09-22
#
#    album popularity  duration  explicit  popularity
# 0                72    186986     False          81
# 1                52    186986     False          63
# 2                43    221607     False          54
# 3                40    205500     False          52
# 4                69    177302     False          80

# %%
data_np = np.array(raw_data)

for i in range(len(data_np)):
    data_np[i][2] = data_np[i][2].split(',')
    data_np[i][3] = data_np[i][3].split(',') if type(data_np[i][3]) != float else ['Untitled']
    data_np[i][4] = list(map(int, data_np[i][4].split(',')))
    data_np[i][5] = list(map(int, data_np[i][5].split(',')))
    data_np[i][6] = int(data_np[i][6])
    data_np[i][8] = datetime.strptime(data_np[i][8], '%Y-%m-%d')
    data_np[i][9] = int(data_np[i][9])
    data_np[i][10] = int(data_np[i][10])
    data_np[i][11] = 0 if data_np[i][11] == 'False' else 1
    data_np[i][12] = int(data_np[i][12])

# %%
songs_data = pd.DataFrame(data_np, columns=raw_data.columns)
songs_data.head()
# Out:
#                        id                             name  \
# 0  2BgEsaKNfHUdlh97KmvFyo                             2002
# 1  4Pbg79cTBu4vgSphoyNq3j                             2002
# 2  2zYc8JUkCUqY7r567OzpUc             Replay trên con Guây
# 3  3gZyjgWdEibTsQFEmGiSSk    2022 World Championship Theme
# 4  5aucVLKiumD89mxVCB4zvS  Rush Hour (Feat. j-hope of BTS)
#
#                 artist                                             genres  \
# 0         [Anne-Marie]  [dance pop, pop, pop dance, post-teen pop, tro...
# 1         [Anne-Marie]  [dance pop, pop, pop dance, post-teen pop, tro...
# 2    [Phuc Du, Đan Ni]                                            [v-pop]
# 3  [League of Legends]                       [speedrun, video game music]
# 4      [Crush, j-hope]                  [k-pop, korean r&b, k-pop, k-rap]
#
#              followers artist popularity markets  \
# 0           [10179165]              [76]     183
# 1           [10179165]              [76]     183
# 2           [15757, 5]          [46, 36]     183
# 3            [1515248]              [78]     183
# 4  [1049749, 12281987]          [67, 73]     180
#
#                            album release date album popularity duration  \
# 0       Speak Your Mind (Deluxe)   2018-04-27               72   186986
# 1                           2002   2018-04-19               52   186986
# 2           Replay trên con Guây   2022-10-10               43   221607
# 3  2022 World Championship Theme   2022-09-07               40   205500
# 4                      Rush Hour   2022-09-22               69   177302
#
#   explicit popularity
# 0        1         81
# 1        1         63
# 2        1         54
# 3        1         52
# 4        1         80

# %%
def powerOfTwo(n):
    return n**2

# %%
data_np_copy = np.copy(data_np)

for i in range(len(data_np_copy)):
    data_np_copy[i][4] = int(np.sqrt(np.sum(list(map(powerOfTwo, data_np_copy[i][4])))))
    data_np_copy[i][5] = int(np.sqrt(np.sum(list(map(powerOfTwo, data_np_copy[i][5])))))

standard_data = np.array([[col for col in line if type(col) == int] for line in data_np_copy])

# %%
model_data = pd.DataFrame(standard_data, columns=['followers', 'artist popularity', 'markets', 'album popularity', 'duration', 'explicit', 'popularity'])
model_data.head()
# Out:
#    followers  artist popularity  markets  album popularity  duration  \
# 0   10179165                 76      183                72    186986
# 1   10179165                 76      183                52    186986
# 2      15757                 58      183                43    221607
# 3    1515248                 78      183                40    205500
# 4   12326766                 99      180                69    177302
#
#    explicit  popularity
# 0         1          81
# 1         1          63
# 2         1          54
# 3         1          52
# 4         1          80

# %%
songs_train = model_data.iloc[50:]
songs_test = model_data.iloc[:50]

train_features = model_data.iloc[:, :-1]
train_label = model_data.iloc[:, -1]
test_features = model_data.iloc[:, :-1]
test_label = model_data.iloc[:, -1]

# %%
train_features.head()
# Out:
#    followers  artist popularity  markets  album popularity  duration  explicit
# 0   10179165                 76      183                72    186986         1
# 1   10179165                 76      183                52    186986         1
# 2      15757                 58      183                43    221607         1
# 3    1515248                 78      183                40    205500         1
# 4   12326766                 99      180                69    177302         1

# %%
pd.DataFrame(train_label).head()
# Out:
#    popularity
# 0          81
# 1          63
# 2          54
# 3          52
# 4          80

# %%
test_features.head()
# Out:
#    followers  artist popularity  markets  album popularity  duration  explicit
# 0   10179165                 76      183                72    186986         1
# 1   10179165                 76      183                52    186986         1
# 2      15757                 58      183                43    221607         1
# 3    1515248                 78      183                40    205500         1
# 4   12326766                 99      180                69    177302         1

# %%
pd.DataFrame(test_label).head()
# Out:
#    popularity
# 0          81
# 1          63
# 2          54
# 3          52
# 4          80

# %%
# query maximum number of artists in 1 song
max_artist = 0
idx = 0
for i in range(len(data_np)):
    if len(data_np[i][2]) > max_artist:
        max_artist = len(data_np[i][2])
        idx = i
max_artist, idx
# Out:
# (10, 221)
