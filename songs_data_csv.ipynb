# %%
import numpy as np
import pandas as pd
from datetime import datetime

# %%
raw_data = pd.read_csv('songs_data.tsv', sep='\t')
raw_data.head()
# Out:
#                        id                           name  \
# 0  2BgEsaKNfHUdlh97KmvFyo                           2002
# 1  10SRMwb9EuVS1K9rYsBfHQ                    Yet To Come
# 2  3nqQXoyQOWXiESFLlDF1hG      Unholy (feat. Kim Petras)
# 3  3gZyjgWdEibTsQFEmGiSSk  2022 World Championship Theme
# 4  4Pbg79cTBu4vgSphoyNq3j                           2002
#
#                  artist                                             genres  \
# 0            Anne-Marie  post-teen pop,pop dance,uk pop,dance pop,pop,t...
# 1                   BTS                              k-pop,k-pop boy group
# 2  Sam Smith,Kim Petras        post-teen pop,uk pop,transpop,dance pop,pop
# 3     League of Legends                          video game music,speedrun
# 4            Anne-Marie  post-teen pop,pop dance,uk pop,dance pop,pop,t...
#
#          followers artist popularity  markets                          album  \
# 0         10204563                76      183       Speak Your Mind (Deluxe)
# 1         57153603                90      183                          Proof
# 2  20698155,823255             87,82      182      Unholy (feat. Kim Petras)
# 3          1518468                78      183  2022 World Championship Theme
# 4         10204563                76      183                           2002
#
#   release date  album popularity  duration  explicit  popularity
# 0   2018-04-27                72    186986     False          81
# 1   2022-06-10                84    193593     False          85
# 2   2022-09-22                88    156943     False         100
# 3   2022-09-07                40    205500     False          51
# 4   2018-04-19                52    186986     False          63

# %%
data_np = np.array(raw_data)

for i in range(len(data_np)):
    data_np[i, 2] = data_np[i, 2].split(',')
    data_np[i, 3] = data_np[i, 3].split(',') if type(data_np[i, 3]) != float else ['Untitled']
    data_np[i, 4] = list(map(int, data_np[i, 4].split(',')))
    data_np[i, 5] = list(map(int, data_np[i, 5].split(',')))
    data_np[i, 6] = int(data_np[i, 6])
    data_np[i, 8] = datetime.strptime(data_np[i, 8], '%Y-%m-%d') if '-' in data_np[i, 8] else datetime.strptime(data_np[i, 8], '%Y')
    data_np[i, 9] = int(data_np[i, 9])
    data_np[i, 10] = int(data_np[i, 10])
    data_np[i, 11] = 0 if data_np[i, 11] == False else 1
    data_np[i, 12] = int(data_np[i, 12])

# %%
songs_data = pd.DataFrame(data_np, columns=raw_data.columns)
songs_data.head()
# Out:
#                        id                           name  \
# 0  2BgEsaKNfHUdlh97KmvFyo                           2002
# 1  10SRMwb9EuVS1K9rYsBfHQ                    Yet To Come
# 2  3nqQXoyQOWXiESFLlDF1hG      Unholy (feat. Kim Petras)
# 3  3gZyjgWdEibTsQFEmGiSSk  2022 World Championship Theme
# 4  4Pbg79cTBu4vgSphoyNq3j                           2002
#
#                     artist                                             genres  \
# 0             [Anne-Marie]  [post-teen pop, pop dance, uk pop, dance pop, ...
# 1                    [BTS]                           [k-pop, k-pop boy group]
# 2  [Sam Smith, Kim Petras]  [post-teen pop, uk pop, transpop, dance pop, pop]
# 3      [League of Legends]                       [video game music, speedrun]
# 4             [Anne-Marie]  [post-teen pop, pop dance, uk pop, dance pop, ...
#
#             followers artist popularity markets  \
# 0          [10204563]              [76]     183
# 1          [57153603]              [90]     183
# 2  [20698155, 823255]          [87, 82]     182
# 3           [1518468]              [78]     183
# 4          [10204563]              [76]     183
#
#                            album release date album popularity duration  \
# 0       Speak Your Mind (Deluxe)   2018-04-27               72   186986
# 1                          Proof   2022-06-10               84   193593
# 2      Unholy (feat. Kim Petras)   2022-09-22               88   156943
# 3  2022 World Championship Theme   2022-09-07               40   205500
# 4                           2002   2018-04-19               52   186986
#
#   explicit popularity
# 0        0         81
# 1        0         85
# 2        0        100
# 3        0         51
# 4        0         63

# %%
data_np_copy = np.copy(data_np)

for i in range(len(data_np_copy)):
    data_np_copy[i, 4] = int(np.sqrt(np.sum(list(map(lambda x: x**2, data_np_copy[i, 4])))))
    data_np_copy[i, 5] = min(100, int(np.sqrt(np.sum(list(map(lambda x: x**2, data_np_copy[i, 5]))))))

standard_data = np.array([[col for col in line if type(col) == int] for line in data_np_copy])

# %%
model_data = pd.DataFrame(standard_data, columns=['followers', 'artist popularity', 'markets', 'album popularity', 'duration', 'explicit', 'popularity'])
model_data.iloc[1359]
# Out:
# followers            1010046
# artist popularity        100
# markets                  183
# album popularity          22
# duration              286306
# explicit                   0
# popularity                32
# Name: 1359, dtype: int64

# %%
songs_train = model_data.iloc[100:]
songs_test = model_data.iloc[:100]

train_features = songs_train.iloc[:, :-1]
train_label = songs_train.iloc[:, -1]
test_features = songs_test.iloc[:, :-1]
test_label = songs_test.iloc[:, -1]

# %%
train_features.head()
# Out:
#      followers  artist popularity  markets  album popularity  duration  \
# 100    7280850                 75      180                69    220779
# 101      88082                 64      183                50    218250
# 102    1344875                 73      182                75    176973
# 103    1344875                 73      183                72    177186
# 104      78577                100      183                78    163025
#
#      explicit
# 100         0
# 101         0
# 102         0
# 103         0
# 104         0

# %%
pd.DataFrame(train_label).head()
# Out:
#      popularity
# 100          80
# 101          60
# 102          86
# 103          83
# 104          89

# %%
test_features.head()
# Out:
#    followers  artist popularity  markets  album popularity  duration  explicit
# 0   10204563                 76      183                72    186986         0
# 1   57153603                 90      183                84    193593         0
# 2   20714520                100      182                88    156943         0
# 3    1518468                 78      183                40    205500         0
# 4   10204563                 76      183                52    186986         0

# %%
pd.DataFrame(test_label).head()
# Out:
#    popularity
# 0          81
# 1          85
# 2         100
# 3          51
# 4          63

# %%
# query maximum number of artists in 1 song
max_artist = 0
idx = 0
for i in range(len(data_np)):
    if len(data_np[i][2]) > max_artist:
        max_artist = len(data_np[i][2])
        idx = i
max_artist, idx
# Out:
# (39, 1359)
